# %% [markdown]
# <a href="https://colab.research.google.com/github/20Engma/Absher-challenges-2024-SHEHAB1/blob/main/SEHABYOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue May  7 09:44:04 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0              25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 kB 7.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import os

from ultralytics import YOLO

# %%
model = YOLO("yolov8n.yaml")

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR='/content/gdrive/MyDrive/SEHAB.v1i.yolov8'

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100)  # train the model
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/data'

# %%
from PIL import Image
import os
image = "/content/22.jpg","/content/11.jpg"
model = YOLO ("/content/runs/detect/train/weights/best.pt")
result = model.predict(source=image, conf=0.2 ,
                       save=True)
# Out:
# 0: 640x640 1 wrong Car, 146.3ms
# 1: 640x640 1 Wrong-car, 146.3ms
# Speed: 2.9ms preprocess, 146.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
from IPython.display import Image, display

# Display the image
display(Image(filename='/content/runs/detect/predict/11.jpg'))

# %%
from IPython.display import Image, display

# Display the image
display(Image(filename='/content/runs/detect/predict/22.jpg'))

# %%
from IPython.display import Image, display

# Display the image
display(Image(filename='/content/runs/detect/train/results.png'))

# %%
import pandas as pd

df = pd.read_csv('/content/runs/detect/train/results.csv')

print(df.head())
# Out:
#                      epoch           train/box_loss           train/cls_loss  \
# 0                        1                   3.3532                   7.0730
# 1                        2                   3.3184                   6.3019
# 2                        3                   3.1768                   5.8842
# 3                        4                   3.0148                   5.5992
# 4                        5                   2.8951                   5.1394
#
#             train/dfl_loss     metrics/precision(B)        metrics/recall(B)  \
# 0                   4.3205                  0.00034                  0.18277
# 1                   4.0961                  0.00035                  0.18277
# 2                   3.7963                  0.00060                  0.20451
# 3                   3.4907                  0.00084                  0.50805
# 4                   3.2964                  0.50368                  0.01852
#
# ...
